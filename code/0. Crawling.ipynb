# %% [markdown]
# #Crawling Data

# %%
# Upload data from Google Drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !pip install twint

# %%
# !pip install tweepy

# %%
import tweepy

# %%
import twint
import nest_asyncio
import pandas as pd
pd.options.mode.chained_assignment = None 
import json

from datetime import datetime
import time
import numpy as np
import base64
import requests
from tqdm import tqdm

nest_asyncio.apply()

# %%
c = twint.Config()

# %%
c.Search = 'pinjol'
c.Lang = 'id'
# c.Since = '2020-01-01'
# c.Until = '2020-12-31'
# # # ---
c.Since = '2021-01-01'
c.Until = '2021-08-31'
c.Count = True
c.Retweets = True
c.Stats = True
c.Show_hashtags = True
# c.Hide_output = True
c.Profile_full = True
c.Store_csv = True
c.Output = './pinjol.csv'
twint.run.Search(c)

# %%
import twint
#configuration
c = twint.Config()
c.Search = "pinjol"
c.Limit = 10
#running search
twint.run.Search(c)
# Out:
# CRITICAL:root:twint.run:Twint:Feed:noDataExpecting value: line 1 column 1 (char 0)
# sleeping for 1.0 secs
# CRITICAL:root:twint.run:Twint:Feed:noDataExpecting value: line 1 column 1 (char 0)
# sleeping for 8.0 secs
# CRITICAL:root:twint.run:Twint:Feed:noDataExpecting value: line 1 column 1 (char 0)
# sleeping for 27.0 secs
# CRITICAL:root:twint.run:Twint:Feed:noDataExpecting value: line 1 column 1 (char 0)
# sleeping for 64.0 secs
# CRITICAL:root:twint.run:Twint:Feed:noDataExpecting value: line 1 column 1 (char 0)
# sleeping for 125.0 secs
# CRITICAL:root:twint.run:Twint:Feed:noDataExpecting value: line 1 column 1 (char 0)
# sleeping for 216.0 secs
# CRITICAL:root:twint.run:Twint:Feed:noDataExpecting value: line 1 column 1 (char 0)
# sleeping for 343.0 secs
# CRITICAL:root:twint.run:Twint:Feed:noDataExpecting value: line 1 column 1 (char 0)
# sleeping for 512.0 secs
# CRITICAL:root:twint.run:Twint:Feed:noDataExpecting value: line 1 column 1 (char 0)
# sleeping for 729.0 secs
# ...

# %%
list_key =["vaksinasi covid nasional OR imunisasi covid nasional",
          "vaksinasi lansia OR percepatan vaksinasi",
          "vaksinasi masal OR vaksinasi nakes" ,
          "vaksinasi anak dan remaja OR vaksinasi dosis ketiga OR vaksinasi boosterl",
          "vaksinasi BUMN OR vaksinasi tahap 1",
          "vaksinasi tahap 2 OR vaksinasi tahap 3",
          "sertifikat vaksinasi OR vaksinasi palsu",
          "vaksinasi gotong royong OR vaksinasi mandiri",
          "vaksinasi usia 12-17 OR vaksinasi usia 18-59",
          "vaksinasi berbayar OR komorbid vaksinasi"
]

# %%
for i in list_key[5:]:
  print(i)
  c = twint.Config()
  c.Search = i
  c.Lang = 'in'
  # c.Since = '2020-01-01'
  # c.Until = '2020-12-31'
  # # # ---
  c.Since = '2021-01-01'
  c.Until = '2021-08-14'
  c.Count = True
  c.Retweets = True
  c.Stats = True
  c.Show_hashtags = True
  c.Hide_output = True
  # c.Profile_full = True
  c.Store_csv = True
  c.Output = './vaksinasi.csv'
  twint.run.Search(c)
# Out:
# vaksinasi tahap 2 OR vaksinasi tahap 3
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [+] Finished: Successfully collected 1432 Tweets.
# sertifikat vaksinasi OR vaksinasi palsu
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [+] Finished: Successfully collected 75 Tweets.
# vaksinasi gotong royong OR vaksinasi mandiri
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [+] Finished: Successfully collected 617 Tweets.
# vaksinasi usia 12-17 OR vaksinasi usia 18-59
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [+] Finished: Successfully collected 102 Tweets.
# vaksinasi berbayar OR komorbid vaksinasi
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [+] Finished: Successfully collected 4978 Tweets.

# %%
c = twint.Config()
c.Search = "nyeri otot OR chip vaksin"
c.Lang = 'in'
# c.Since = '2020-01-01'
# c.Until = '2020-12-31'
# # ---
c.Since = '2021-01-01'
c.Until = '2021-08-14'
c.Count = True
c.Retweets = True
c.Stats = True
c.Show_hashtags = True
c.Hide_output = True
# c.Profile_full = True
c.Store_csv = True
c.Output = './efeksamping_vaksin.csv'
twint.run.Search(c)
# Out:
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [+] Finished: Successfully collected 262 Tweets.

# %%
df = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/Research/Ibu Diana/Twitter Covid Vaksin/covid5.csv')
df[df['language'].isna()]
# Out:
# Empty DataFrame
# Columns: [id, conversation_id, created_at, date, time, timezone, user_id, username, name, place, tweet, language, mentions, urls, photos, replies_count, retweets_count, likes_count, hashtags, cashtags, link, retweet, quote_url, video, thumbnail, near, geo, source, user_rt_id, user_rt, retweet_id, reply_to, retweet_date, translate, trans_src, trans_dest]
# Index: []

# %%
df = df[df['language']=='in']
df = df.drop_duplicates(subset=['id'])
df = df.reset_index(drop=True)
df
# Out:
#                         id      conversation_id  ... trans_src trans_dest
# 0      1344206054419120128  1344206054419120128  ...       NaN        NaN
# 1      1343523365613690881  1343523365613690881  ...       NaN        NaN
# 2      1342785494933901313  1342785494933901313  ...       NaN        NaN
# 3      1342425490921951237  1342425490921951237  ...       NaN        NaN
# 4      1342387556004941826  1342387556004941826  ...       NaN        NaN
# ...                    ...                  ...  ...       ...        ...
# 12803  1362645897469779971  1362645897469779971  ...       NaN        NaN
# 12804  1362645285575352326  1362645285575352326  ...       NaN        NaN
# 12805  1362645149176635396  1362645149176635396  ...       NaN        NaN
# 12806  1362645108726714369  1362645108726714369  ...       NaN        NaN
# 12807  1362644912861143042  1362644912861143042  ...       NaN        NaN
#
# [12808 rows x 36 columns]

# %%
df.to_csv('/content/gdrive/My Drive/Colab Notebooks/Research/Ibu Diana/Twitter Covid Vaksin/vaksinasi_fix.csv')

# %%
import pandas as pd
df = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/Research/Ibu Diana/Twitter Covid Vaksin/result/vaksinasi_fix.csv')
len(df)
# Out:
# 12810

# %% [markdown]
# - covid : 64K
# - efek samping : 465K
# - efektifitas : 877
# - jenis vaksin: 17K
# - vaksinasi : 12K
